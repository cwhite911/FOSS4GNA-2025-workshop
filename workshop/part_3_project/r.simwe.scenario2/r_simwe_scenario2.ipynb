# %% [markdown]
# # r.simwe.scenario2
#
# This notebook runs the example from r.simwe.scenario2's manual page and visualizes the output.
#
# ## Setup
#
# We will be using the NC SPM sample location.

# %%
import subprocess
import sys

# Ask GRASS where its Python packages are.
sys.path.append(
    subprocess.check_output(["grass", "--config", "python_path"], text=True).strip()
)

# Import GRASS packages
import grass.script as gs
import grass.jupyter as gj
from grass.tools import Tools

# Start GRASS Session
session = gj.init("~/data/grassdata/nc_basic_spm_grass7/user1")
tools = Tools(session=session)

# %% [markdown]
# ## Create example from the tool's documentation

# %%
r_simwe_scenario2_input = "elevation"
r_simwe_scenario2_output = "output"

with gs.RegionManager(raster=r_simwe_scenario2_input):
    tools.r_simwe_scenario2(
        input=r_simwe_scenario2_input,
        output=r_simwe_scenario2_output
    )

# %%
r_simwe_scenario2_map = gj.Map()
r_simwe_scenario2_map.d_rast(map=r_simwe_scenario2_output)
r_simwe_scenario2_map.show()
